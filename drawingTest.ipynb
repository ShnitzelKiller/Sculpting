# %%
include("canvas.jl")
# Out:
# clear! (generic function with 1 method)

# %%
using Images

# %%
function display_normals!(image::Matrix{RGB{T}}, normals::Array{T,3}, dists::Matrix{T}) where {T <: AbstractFloat}
    for I in CartesianIndices(image)
        rg = @view normals[:,I]
        dist = dists[I]
        fac = dist < 0 ? 0.5 : 1.0
        t(x) = (x*0.3+0.5)*fac
        image[I] = RGB(t(rg[1]), t(rg[2]), fac*0.5)
    end
    return image
end
function display_normals(normals::Array{T,3}, dists::Matrix{T}) where {T <: AbstractFloat}
    image = Array{RGB{T}}(undef, size(normals)[2:end]...)::Array{RGB{T}, 2}
    return display_normals!(image, normals, dists)'
end
display_normals(canvas::Canvas) = display_normals(canvas.normals, canvas.grid)
# Out:
# display_normals (generic function with 2 methods)

# %%
canvas = Canvas(10, 10, 0.025, 4);

# %%
clear!(canvas)
circle1 = Circle(3.0, Transform(5, 5))
circle2 = Circle(3.0, Transform(5, 7))
shape = Intersect([circle1, Negate(circle2)], Transform())
draw!(canvas, shape)
display_normals(canvas)
# Out:
# 400×400 LinearAlgebra.Adjoint{RGB{Float64},Array{RGB{Float64},2}}:
#  RGB{Float64}(0.5,0.5,0.5)            …  RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.382393,0.442266,0.5)     RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.286266,0.337007,0.5)     RGB{Float64}(0.615466,0.444405,0.5)
#  RGB{Float64}(0.285729,0.289755,0.5)     RGB{Float64}(0.714795,0.339688,0.5)
#  RGB{Float64}(0.285191,0.290304,0.5)  …  RGB{Float64}(0.715332,0.290841,0.5)
#  RGB{Float64}(0.284652,0.290856,0.5)     RGB{Float64}(0.715869,0.291394,0.5)
#  RGB{Float64}(0.284112,0.291413,0.5)     RGB{Float64}(0.716408,0.291952,0.5)
#  RGB{Float64}(0.28357,0.291974,0.5)      RGB{Float64}(0.716949,0.292514,0.5)
#  RGB{Float64}(0.283027,0.292539,0.5)     RGB{Float64}(0.71749,0.293081,0.5)
#  RGB{Float64}(0.282482,0.293108,0.5)  …  RGB{Float64}(0.718033,0.293652,0.5)
#  RGB{Float64}(0.281937,0.293682,0.5)     RGB{Float64}(0.718577,0.294227,0.5)
#  RGB{Float64}(0.28139,0.29426,0.5)       RGB{Float64}(0.719122,0.294806,0.5)
#  ⋮                                    ⋱
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)            …  RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)            …  RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)

# %%
displace!(canvas, 1.0)
display_normals(canvas)
# Out:
# 400×400 LinearAlgebra.Adjoint{RGB{Float64},Array{RGB{Float64},2}}:
#  RGB{Float64}(0.287868,0.287868,0.5)  …  RGB{Float64}(0.712662,0.288399,0.5)
#  RGB{Float64}(0.287335,0.288135,0.5)     RGB{Float64}(0.713193,0.288667,0.5)
#  RGB{Float64}(0.286801,0.288671,0.5)     RGB{Float64}(0.713726,0.289204,0.5)
#  RGB{Float64}(0.286266,0.289211,0.5)     RGB{Float64}(0.71426,0.289745,0.5)
#  RGB{Float64}(0.285729,0.289755,0.5)     RGB{Float64}(0.714795,0.290291,0.5)
#  RGB{Float64}(0.285191,0.290304,0.5)  …  RGB{Float64}(0.715332,0.290841,0.5)
#  RGB{Float64}(0.284652,0.290856,0.5)     RGB{Float64}(0.715869,0.291394,0.5)
#  RGB{Float64}(0.284112,0.291413,0.5)     RGB{Float64}(0.716408,0.291952,0.5)
#  RGB{Float64}(0.28357,0.291974,0.5)      RGB{Float64}(0.716949,0.292514,0.5)
#  RGB{Float64}(0.283027,0.292539,0.5)     RGB{Float64}(0.71749,0.293081,0.5)
#  RGB{Float64}(0.282482,0.293108,0.5)  …  RGB{Float64}(0.718033,0.293652,0.5)
#  RGB{Float64}(0.281937,0.293682,0.5)     RGB{Float64}(0.718577,0.294227,0.5)
#  RGB{Float64}(0.28139,0.29426,0.5)       RGB{Float64}(0.719122,0.294806,0.5)
#  ⋮                                    ⋱
#  RGB{Float64}(0.348619,0.759216,0.5)     RGB{Float64}(0.652615,0.758494,0.5)
#  RGB{Float64}(0.349343,0.759635,0.5)     RGB{Float64}(0.651888,0.758919,0.5)
#  RGB{Float64}(0.350061,0.760048,0.5)  …  RGB{Float64}(0.651167,0.759338,0.5)
#  RGB{Float64}(0.350774,0.760455,0.5)     RGB{Float64}(0.650452,0.759751,0.5)
#  RGB{Float64}(0.351481,0.760856,0.5)     RGB{Float64}(0.649743,0.760158,0.5)
#  RGB{Float64}(0.352182,0.761252,0.5)     RGB{Float64}(0.649039,0.76056,0.5)
#  RGB{Float64}(0.352878,0.761642,0.5)     RGB{Float64}(0.64834,0.760956,0.5)
#  RGB{Float64}(0.353569,0.762027,0.5)  …  RGB{Float64}(0.647647,0.761346,0.5)
#  RGB{Float64}(0.354254,0.762406,0.5)     RGB{Float64}(0.646959,0.761731,0.5)
#  RGB{Float64}(0.354934,0.76278,0.5)      RGB{Float64}(0.646276,0.762111,0.5)
#  RGB{Float64}(0.355608,0.763149,0.5)     RGB{Float64}(0.645599,0.762485,0.5)
#  RGB{Float64}(0.356277,0.763332,0.5)     RGB{Float64}(0.644927,0.762671,0.5)

# %%
circle3 = Circle(2.0, Transform(5, 5))
draw!(canvas, circle3)
display_normals(canvas)
# Out:
# 400×400 LinearAlgebra.Adjoint{RGB{Float64},Array{RGB{Float64},2}}:
#  RGB{Float64}(0.287868,0.287868,0.5)  …  RGB{Float64}(0.712662,0.288399,0.5)
#  RGB{Float64}(0.287335,0.288135,0.5)     RGB{Float64}(0.713193,0.288667,0.5)
#  RGB{Float64}(0.286801,0.288671,0.5)     RGB{Float64}(0.713726,0.289204,0.5)
#  RGB{Float64}(0.286266,0.289211,0.5)     RGB{Float64}(0.71426,0.289745,0.5)
#  RGB{Float64}(0.285729,0.289755,0.5)     RGB{Float64}(0.714795,0.290291,0.5)
#  RGB{Float64}(0.285191,0.290304,0.5)  …  RGB{Float64}(0.715331,0.290841,0.5)
#  RGB{Float64}(0.284652,0.290856,0.5)     RGB{Float64}(0.715869,0.291394,0.5)
#  RGB{Float64}(0.284112,0.291413,0.5)     RGB{Float64}(0.716408,0.291952,0.5)
#  RGB{Float64}(0.28357,0.291974,0.5)      RGB{Float64}(0.716949,0.292514,0.5)
#  RGB{Float64}(0.283027,0.292539,0.5)     RGB{Float64}(0.71749,0.293081,0.5)
#  RGB{Float64}(0.282482,0.293108,0.5)  …  RGB{Float64}(0.718033,0.293651,0.5)
#  RGB{Float64}(0.281937,0.293682,0.5)     RGB{Float64}(0.718577,0.294226,0.5)
#  RGB{Float64}(0.28139,0.29426,0.5)       RGB{Float64}(0.719122,0.294806,0.5)
#  ⋮                                    ⋱
#  RGB{Float64}(0.348587,0.759197,0.5)     RGB{Float64}(0.65251,0.758556,0.5)
#  RGB{Float64}(0.34931,0.759615,0.5)      RGB{Float64}(0.651783,0.758981,0.5)
#  RGB{Float64}(0.350027,0.760028,0.5)  …  RGB{Float64}(0.651062,0.759399,0.5)
#  RGB{Float64}(0.350738,0.760434,0.5)     RGB{Float64}(0.650347,0.759812,0.5)
#  RGB{Float64}(0.351444,0.760835,0.5)     RGB{Float64}(0.649637,0.760219,0.5)
#  RGB{Float64}(0.352144,0.76123,0.5)      RGB{Float64}(0.648933,0.76062,0.5)
#  RGB{Float64}(0.352839,0.761619,0.5)     RGB{Float64}(0.648235,0.761015,0.5)
#  RGB{Float64}(0.353528,0.762003,0.5)  …  RGB{Float64}(0.647542,0.761405,0.5)
#  RGB{Float64}(0.354211,0.762382,0.5)     RGB{Float64}(0.646854,0.761789,0.5)
#  RGB{Float64}(0.35489,0.762755,0.5)      RGB{Float64}(0.646172,0.762168,0.5)
#  RGB{Float64}(0.355563,0.763124,0.5)     RGB{Float64}(0.645496,0.762542,0.5)
#  RGB{Float64}(0.35623,0.763306,0.5)      RGB{Float64}(0.644825,0.762728,0.5)

# %%
displace!(canvas, -1)
display_normals(canvas)
# Out:
# 400×400 LinearAlgebra.Adjoint{RGB{Float64},Array{RGB{Float64},2}}:
#  RGB{Float64}(0.5,0.5,0.5)            …  RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.444843,0.473488,0.5)     RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.286271,0.368226,0.5)     RGB{Float64}(0.553018,0.475623,0.5)
#  RGB{Float64}(0.285736,0.28975,0.5)      RGB{Float64}(0.714787,0.370901,0.5)
#  RGB{Float64}(0.285199,0.290296,0.5)  …  RGB{Float64}(0.715322,0.290831,0.5)
#  RGB{Float64}(0.284662,0.290847,0.5)     RGB{Float64}(0.715858,0.291383,0.5)
#  RGB{Float64}(0.284123,0.291402,0.5)     RGB{Float64}(0.716395,0.29194,0.5)
#  RGB{Float64}(0.283583,0.291961,0.5)     RGB{Float64}(0.716934,0.2925,0.5)
#  RGB{Float64}(0.283041,0.292524,0.5)     RGB{Float64}(0.717474,0.293064,0.5)
#  RGB{Float64}(0.282499,0.293092,0.5)  …  RGB{Float64}(0.718015,0.293633,0.5)
#  RGB{Float64}(0.281955,0.293664,0.5)     RGB{Float64}(0.718557,0.294206,0.5)
#  RGB{Float64}(0.28141,0.29424,0.5)       RGB{Float64}(0.719101,0.294784,0.5)
#  ⋮                                    ⋱
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)            …  RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)            …  RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)

# %%
include("selectors.jl")
# Out:
# selectnorm (generic function with 1 method)

# %%
displace!(canvas, 1.0, selectnorm(pi/2, 2))
display_normals(canvas)
# Out:
# 400×400 LinearAlgebra.Adjoint{RGB{Float64},Array{RGB{Float64},2}}:
#  RGB{Float64}(0.5,0.5,0.5)            …  RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.446112,0.474122,0.5)     RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.286271,0.368861,0.5)     RGB{Float64}(0.551749,0.476257,0.5)
#  RGB{Float64}(0.285736,0.28975,0.5)      RGB{Float64}(0.714787,0.371536,0.5)
#  RGB{Float64}(0.285199,0.290296,0.5)  …  RGB{Float64}(0.715322,0.290832,0.5)
#  RGB{Float64}(0.284661,0.290847,0.5)     RGB{Float64}(0.715858,0.291384,0.5)
#  RGB{Float64}(0.284123,0.291402,0.5)     RGB{Float64}(0.716396,0.29194,0.5)
#  RGB{Float64}(0.283582,0.291961,0.5)     RGB{Float64}(0.716934,0.2925,0.5)
#  RGB{Float64}(0.283041,0.292525,0.5)     RGB{Float64}(0.717474,0.293065,0.5)
#  RGB{Float64}(0.282498,0.293092,0.5)  …  RGB{Float64}(0.718016,0.293634,0.5)
#  RGB{Float64}(0.281954,0.293664,0.5)     RGB{Float64}(0.718558,0.294207,0.5)
#  RGB{Float64}(0.281409,0.294241,0.5)     RGB{Float64}(0.719101,0.294784,0.5)
#  ⋮                                    ⋱
#  RGB{Float64}(0.329033,0.746818,0.5)     RGB{Float64}(0.672225,0.745945,0.5)
#  RGB{Float64}(0.329908,0.747419,0.5)     RGB{Float64}(0.671349,0.746552,0.5)
#  RGB{Float64}(0.330776,0.74801,0.5)   …  RGB{Float64}(0.67048,0.74715,0.5)
#  RGB{Float64}(0.331638,0.748592,0.5)     RGB{Float64}(0.669618,0.747739,0.5)
#  RGB{Float64}(0.332494,0.749165,0.5)     RGB{Float64}(0.668762,0.748319,0.5)
#  RGB{Float64}(0.333342,0.74973,0.5)      RGB{Float64}(0.667913,0.74889,0.5)
#  RGB{Float64}(0.334184,0.750286,0.5)     RGB{Float64}(0.66707,0.749453,0.5)
#  RGB{Float64}(0.33502,0.750835,0.5)   …  RGB{Float64}(0.666234,0.750008,0.5)
#  RGB{Float64}(0.335849,0.751375,0.5)     RGB{Float64}(0.665404,0.750554,0.5)
#  RGB{Float64}(0.336672,0.751906,0.5)     RGB{Float64}(0.66458,0.751093,0.5)
#  RGB{Float64}(0.337488,0.752431,0.5)     RGB{Float64}(0.663763,0.751623,0.5)
#  RGB{Float64}(0.338298,0.752691,0.5)     RGB{Float64}(0.662952,0.751886,0.5)

# %%
square=Square(1.0, Transform(5, 2, pi/4))
draw!(canvas, square)
display_normals(canvas)
# Out:
# 400×400 LinearAlgebra.Adjoint{RGB{Float64},Array{RGB{Float64},2}}:
#  RGB{Float64}(0.5,0.5,0.5)            …  RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.5,0.5,0.5)               RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.441477,0.473116,0.5)     RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(0.285333,0.368333,0.5)     RGB{Float64}(0.553761,0.47599,0.5)
#  RGB{Float64}(0.285064,0.290571,0.5)     RGB{Float64}(0.715308,0.371536,0.5)
#  RGB{Float64}(0.284722,0.290885,0.5)  …  RGB{Float64}(0.715692,0.29129,0.5)
#  RGB{Float64}(0.284324,0.291267,0.5)     RGB{Float64}(0.716119,0.29171,0.5)
#  RGB{Float64}(0.283886,0.291699,0.5)     RGB{Float64}(0.716578,0.29217,0.5)
#  RGB{Float64}(0.283417,0.292171,0.5)     RGB{Float64}(0.717062,0.292662,0.5)
#  RGB{Float64}(0.282926,0.292671,0.5)     RGB{Float64}(0.717563,0.293178,0.5)
#  RGB{Float64}(0.282419,0.293194,0.5)  …  RGB{Float64}(0.718076,0.293713,0.5)
#  RGB{Float64}(0.2819,0.293735,0.5)       RGB{Float64}(0.7186,0.294262,0.5)
#  RGB{Float64}(0.281372,0.294289,0.5)     RGB{Float64}(0.71913,0.294822,0.5)
#  ⋮                                    ⋱
#  RGB{Float64}(0.329017,0.746807,0.5)     RGB{Float64}(0.672228,0.745943,0.5)
#  RGB{Float64}(0.329891,0.747407,0.5)     RGB{Float64}(0.671353,0.746549,0.5)
#  RGB{Float64}(0.330759,0.747997,0.5)  …  RGB{Float64}(0.670485,0.747147,0.5)
#  RGB{Float64}(0.33162,0.748579,0.5)      RGB{Float64}(0.669623,0.747735,0.5)
#  RGB{Float64}(0.332474,0.749152,0.5)     RGB{Float64}(0.668767,0.748315,0.5)
#  RGB{Float64}(0.333322,0.749716,0.5)     RGB{Float64}(0.667919,0.748886,0.5)
#  RGB{Float64}(0.334163,0.750272,0.5)     RGB{Float64}(0.667076,0.749449,0.5)
#  RGB{Float64}(0.334998,0.75082,0.5)   …  RGB{Float64}(0.66624,0.750003,0.5)
#  RGB{Float64}(0.335826,0.751359,0.5)     RGB{Float64}(0.665411,0.750549,0.5)
#  RGB{Float64}(0.336648,0.751891,0.5)     RGB{Float64}(0.664588,0.751088,0.5)
#  RGB{Float64}(0.337463,0.752414,0.5)     RGB{Float64}(0.663771,0.751618,0.5)
#  RGB{Float64}(0.338273,0.752674,0.5)     RGB{Float64}(0.66296,0.751881,0.5)
